# %% [markdown]
# # What is Python.....🤔

# %% [markdown]
# <html><p style="font-size:18px">It is programming language</p>
#    <p style="font-size:18px">It is an interpreted, object-oriented, high-level programming language

# %% [markdown]
# ## What is Interpreted ...?

# %% [markdown]
# <html><p style="font-size:16px">An interpreted language is a type of programming language for which there is an <b>interpreter</b> which runs over a virtual machine. The interpreter excutes the code line by line and convert it into low level machine language. Since, the interpreted language runs over virtual environment, these languages are considered platform independent.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Differences Between Interpreter Language and Complied Language

# %% [markdown]
# https://www.geeksforgeeks.org/difference-between-compiled-and-interpreted-language/

# %% [markdown]
# <html>

# %% [markdown]
# # Why python....?

# %% [markdown]
# https://www.upgrad.com/blog/why-learn-python/

# %% [markdown]
# <html>
# <p style="font-size:18px">1) It's Simplicity</p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Applications of Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Career Opportunities

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Datatypes

# %% [markdown]
# https://www.w3schools.com/python/python_datatypes.asp

# %%
#integer
a1=1
#type method is used to get the data type of a variable
type(a1)
# Out:
# int

# %%
#strings
b="abs"
b
print(type(b))
# Out:
# <class 'str'>

# %%
#boolean
c=True
print(c)
print(type(c))
# Out:
# True
# <class 'bool'>

# %%
#list
d=[1,2,3,"ab"]
print(type(d))
# Out:
# <class 'list'>

# %%
#tuples
e=(1,2,3)
print(type(e))
# Out:
# <class 'tuple'>

# %%
#floating 
f=2.3
print(f)
print(type(f))
# Out:
# 2.3
# <class 'float'>

# %%
a={1:3,2:4}
type(a)
# Out:
# dict

# %%
#sets
a={1,23,4}
type(a)
# Out:
# set

# %% [markdown]
# # Key Take aways
# <p>
# 1) We Learnt what is python
#     <p>
# 2) What is programming
# <p>
# 3) Applications of Python
# <p>
# 4) Career Oppur
#   <p>
# 5) Datatypes
